# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/prjct/upload/Suicide_Ideation_Dataset(Twitter-based).csv')

# %%
df.head()
# Out:
#                                                Tweet                  Suicide
# 0                                  making some lunch         Not Suicide post
# 1                        @Alexia You want his money.         Not Suicide post
# 2  @dizzyhrvy that crap took me forever to put to...  Potential Suicide post
# 3  @jnaylor #kiwitweets Hey Jer! Since when did y...         Not Suicide post
# 4  Trying out &quot;Delicious Library 2&quot; wit...         Not Suicide post

# %%
df.tail()
# Out:
#                                                   Tweet           Suicide
# 1782    i have forgotten how much i love my Nokia N95-1  Not Suicide post
# 1783  Starting my day out with a positive attitude! ...  Not Suicide post
# 1784  @belledame222 Hey, it's 5 am...give a girl som...  Not Suicide post
# 1785  2 drunken besties stumble into my room and we ...  Not Suicide post
# 1786  @dancingbonita &quot;I friggin love you!!!&quo...  Not Suicide post

# %%
df['Suicide'].value_counts()
# Out:
# Suicide
# Not Suicide post           1127
# Potential Suicide post      660
# Name: count, dtype: int64

# %%
import re

# %%
def get_clean(x):
    x = re.sub(r"http\S+", "", x)  # Remove URLs
    x = re.sub(r"@\w+", "", x)    # Remove mentions
    x = re.sub(r"[^A-Za-z\s]", "", x)  # Remove special characters
    x = x.lower()  # Convert to lowercase
    return x

# %%
df['Tweet'] = df['Tweet'].fillna("")  # Replace NaN with an empty string

# %%
# Apply preprocessing
df['Tweet'] = df['Tweet'].apply(preprocess_text)
print(df['Tweet'].head())
# Out:
# 0                                    making some lunch
# 1                                   you want his money
# 2    that crap took me forever to put together im g...
# 3    kiwitweets hey jer since when did you start tw...
# 4    trying out quotdelicious library quot with mix...
# Name: Tweet, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Suicide'] = label_encoder.fit_transform(df['Suicide'])
print(label_encoder.classes_)  # Check label mappings

# Now 'Not Suicide' might be encoded as 0, and 'Potential Suicide' as 1
# Out:
# ['Not Suicide post' 'Potential Suicide post ']

# %%
df.head()
# Out:
#                                                Tweet  Suicide
# 0                                  making some lunch        0
# 1                                 you want his money        0
# 2  that crap took me forever to put together im g...        1
# 3  kiwitweets hey jer since when did you start tw...        0
# 4  trying out quotdelicious library quot with mix...        0

# %% [markdown]
# TFIDF

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report

# %%
# TF-IDF Vectorization
tfidf = TfidfVectorizer(max_features=1000,ngram_range=(1,3), analyzer='char')

# %%
x = vectorizer.fit_transform(df['Tweet'])
y = df['Suicide']

# %%
x.shape
# Out:
# (1787, 1000)

# %%
x_train,y_train,x_test,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
clf = LinearSVC()
clf.fit(x_train,x_test)
# Out:
# LinearSVC()

# %%
y_pred = clf.predict(y_train)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       224
#            1       0.88      0.86      0.87       134
#
#     accuracy                           0.91       358
#    macro avg       0.90      0.90      0.90       358
# weighted avg       0.90      0.91      0.90       358

# %% [markdown]
# ### **prediction**

# %%
x = "I feel so lonely and don't know what to do anymore."
x = get_clean(x)
vec = vectorizer.transform([x])
clf.predict(vec)
# Out:
# array([1])

# %%
x = "i am dieing to go for a tour"
x = get_clean(x)
vec = vectorizer.transform([x])
clf.predict(vec)
# Out:
# array([0])
